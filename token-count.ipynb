# %%
data = ''
with open("output-markdown/yaskawa-l1000a.txt", "r" , encoding="utf-8") as f:
  data = f.read()

from token_count import TokenCount
tc = TokenCount(model_name="gpt-3.5-turbo")
text = "Your text here"
tokens = tc.num_tokens_from_string(data)
print(f"Tokens in the string: {tokens}")
# Out:
# Tokens in the string: 478881
